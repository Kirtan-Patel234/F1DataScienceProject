# %%
import pandas as pd

# %%
df = pd.read_csv('race_till_2023.csv')

# %%
df.describe(include='all')
# Out:
#                year                  race  DriverNumber BroadcastName  \
# count   4061.000000                  4061   4061.000000          2537
# unique          NaN                    41           NaN            37
# top             NaN  Hungarian Grand Prix           NaN  M VERSTAPPEN
# freq            NaN                   204           NaN           127
# mean    2018.720758                   NaN     26.764344           NaN
# std        2.874953                   NaN     24.358405           NaN
# min     2014.000000                   NaN      1.000000           NaN
# 25%     2016.000000                   NaN      9.000000           NaN
# 50%     2019.000000                   NaN     20.000000           NaN
# 75%     2021.000000                   NaN     33.000000           NaN
# max     2023.000000                   NaN     99.000000           NaN
#
#        DriverId         FullName  TeamName  GridPosition     Position  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4061 entries, 0 to 4060
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                4061 non-null   int64
#  1   race                4061 non-null   object
#  2   DriverNumber        4061 non-null   int64
#  3   BroadcastName       2537 non-null   object
#  4   DriverId            3982 non-null   object
#  5   FullName            4061 non-null   object
#  6   TeamName            4061 non-null   object
#  7   GridPosition        3980 non-null   float64
#  8   Position            3980 non-null   float64
#  9   ClassifiedPosition  3982 non-null   object
#  10  Time                2026 non-null   object
#  11  Status              3982 non-null   object
#  12  Points              3982 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 412.6+ KB

# %%
import fastf1
session = fastf1.get_session(2019, 'Monza', 'R')
session.load(telemetry=False, laps=True)
lap = session.laps.pick_fastest()
data = session.laps.get_weather_data()
data
# Out:
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.4.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '77', '44', '3', '27', '23', '11', '33', '99', '4', '10', '18', '5', '63', '7', '8', '88', '20', '26', '55']
#                        Time AirTemp Humidity Pressure Rainfall TrackTemp  \
# ...

# %%
data.describe()
# Out:
# /var/folders/h7/24ywb4t1079fb0sd4fmvs2kr0000gn/T/ipykernel_14010/3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
#                           Time  AirTemp  Humidity  Pressure Rainfall  \
# count                      275    275.0     275.0     275.0      275
# unique                      39     12.0      28.0       8.0        1
# top     0 days 00:58:14.672000     23.3      51.5     992.9    False
# freq                        15     50.0      40.0      94.0      275
#
#         TrackTemp  WindDirection  WindSpeed
# count       275.0            275      275.0
# unique       22.0             31       22.0
# top          38.3            207        2.0
# freq         36.0             23       31.0
